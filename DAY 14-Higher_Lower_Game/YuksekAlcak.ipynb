# %%
import art
import game_data 
import random

# %%
game_data.data
# Out:
# [{'name': 'Instagram',
#   'follower_count': 346,
#   'description': 'Social media platform',
#   'country': 'United States'},
#  {'name': 'Cristiano Ronaldo',
#   'follower_count': 215,
#   'description': 'Footballer',
#   'country': 'Portugal'},
#  {'name': 'Ariana Grande',
#   'follower_count': 183,
#   'description': 'Musician and actress',
#   'country': 'United States'},
#  {'name': 'Dwayne Johnson',
#   'follower_count': 181,
#   'description': 'Actor and professional wrestler',
#   'country': 'United States'},
#  {'name': 'Selena Gomez',
#   'follower_count': 174,
#   'description': 'Musician and actress',
#   'country': 'United States'},
#  {'name': 'Kylie Jenner',
#   'follower_count': 172,
#   'description': 'Reality TV personality and businesswoman and Self-Made Billionaire',
#   'country': 'United States'},
#  {'name': 'Kim Kardashian',
#   'follower_count': 167,
#   'description': 'Reality TV personality and businesswoman',
#   'country': 'United States'},
# ...

# %%
data=game_data.data

a=data[0].values()
a
# Out:
# dict_values(['Instagram', 346, 'Social media platform', 'United States'])

# %%
data=game_data.data
data[1]
# Out:
# {'name': 'Cristiano Ronaldo',
#  'follower_count': 215,
#  'description': 'Footballer',
#  'country': 'Portugal'}

# %%
import random
a=random.choice(data)
b=random.choice(data)

print(a["follower_count"])

print(b["follower_count"])

def a_bilgi():
    print(a["name"],a["description"],a["country"])
    print(a["description"])
    print(a["country"])

a_bilgi()

def b_bilgi():
# Out:
# 174
# 66
# Selena Gomez
# Musician and actress
# United States

# %%
data[0].items()
# Out:
# dict_items([('name', 'Instagram'), ('follower_count', 346), ('description', 'Social media platform'), ('country', 'United States')])

# %%
import art
import game_data 
import random
data=game_data.data
ilk=random.choice(data)
iki=random.choice(data)
skor=0
#print(a["follower_count"])

#print(b["follower_count"])

print(art.logo)

print("COMPERA A: ",ilk["name"],",",ilk["description"],",",ilk["country"])

print(art.vs)

print("AGAINST B: " ,iki["name"],",",iki["description"],",",iki["country"])

oyun =True

while oyun:
    secim=input("A'nın mı takipçisi fazla B'nin mi ?").lower()
    if secim=="a" and ilk["follower_count"]> iki["follower_count"]:
        ilk["follower_count"]
        iki=random.choice(data)
        print("COMPERA A: ",ilk["name"],",",ilk["description"],",",ilk["country"])
        print(art.vs)
        print("AGAINST B: " ,iki["name"],",",iki["description"],",",iki["country"])
        skor+=1
        print("skorun: ",skor)
    elif secim=="b" and iki["follower_count"]> ilk["follower_count"]:
        iki["follower_count"]
        ilk=random.choice(data)
        print("COMPERA A: ",ilk["name"],",",ilk["description"],",",ilk["country"])
        print(art.vs)
        print("AGAINST B: " ,iki["name"],",",iki["description"],",",iki["country"])
        skor+=1
        print("skorun: ",skor)
    else:
        oyun=False
        print("oyun bitti skor:",skor)
# Out:
#     __  ___       __
#    / / / (_)___ _/ /_  ___  _____
#   / /_/ / / __ `/ __ \/ _ \/ ___/
#  / __  / / /_/ / / / /  __/ /
# /_/ ///_/\__, /_/ /_/\___/_/
#    / /  /____/_      _____  _____
#   / /   / __ \ | /| / / _ \/ ___/
#  / /___/ /_/ / |/ |/ /  __/ /
# /_____/\____/|__/|__/\___/_/
#
# COMPERA A:  Emma Watson , Actress , United Kingdom
#
#  _    __
# | |  / /____
# | | / / ___/
# | |/ (__  )
# |___/____(_)
#
# AGAINST B:  Katy Perry , Musician , United States
# oyun bitti skor: 0

# %%
import art
import game_data 
import random
data=game_data.data
ilk=random.choice(data)
iki=random.choice(data)
skor=0
#print(a["follower_count"])

#print(b["follower_count"])

print(art.logo)

print("COMPERA A: ",ilk["name"],",",ilk["description"],",",ilk["country"])

print(art.vs)

print("AGAINST B: " ,iki["name"],",",iki["description"],",",iki["country"])

oyun =True

while oyun:
    secim=input("A'nın mı takipçisi fazla B'nin mi ?").lower()
    if secim=="a" and ilk["follower_count"]> iki["follower_count"]:
        ilk["follower_count"]
        iki=random.choice(data)
        print("COMPERA A: ",ilk["name"],",",ilk["description"],",",ilk["country"])
        print(art.vs)
        print("AGAINST B: " ,iki["name"],",",iki["description"],",",iki["country"])
        skor+=1
        print("skorun: ",skor)
    elif secim=="b" and iki["follower_count"]> ilk["follower_count"]:
        ilk=iki
        iki=random.choice(data)
        print("COMPERA A: ",ilk["name"],",",ilk["description"],",",ilk["country"])
        print(art.vs)
        print("AGAINST B: " ,iki["name"],",",iki["description"],",",iki["country"])
        skor+=1
        print("skorun: ",skor)
    else:
        oyun=False
        print("oyun bitti skor:",skor)
# Out:
#     __  ___       __
#    / / / (_)___ _/ /_  ___  _____
#   / /_/ / / __ `/ __ \/ _ \/ ___/
#  / __  / / /_/ / / / /  __/ /
# /_/ ///_/\__, /_/ /_/\___/_/
#    / /  /____/_      _____  _____
#   / /   / __ \ | /| / / _ \/ ___/
#  / /___/ /_/ / |/ |/ /  __/ /
# /_____/\____/|__/|__/\___/_/
#
# COMPERA A:  Nicki Minaj , Musician , Trinidad and Tobago
#
#  _    __
# | |  / /____
# | | / / ___/
# | |/ (__  )
# |___/____(_)
#
# AGAINST B:  Justin Bieber , Musician , Canada
# COMPERA A:  Justin Bieber , Musician , Canada
#
#  _    __
# | |  / /____
# | | / / ___/
# | |/ (__  )
# |___/____(_)
#
# AGAINST B:  Kendall Jenner , Reality TV personality and Model , United States
# skorun:  1
# oyun bitti skor: 1
