# %% [markdown]
# RASTGELE BİR KELİME OLUŞTUR.
#
# WORDDEKİ HARF SAYISI KADAR BOŞLUK OLUŞTURUN.
#
# KULLANICIDAN TAHMİN ETMESİNİ İSTEYİN..
#
# TAHMİN EDİLEN HARF KELİMEDE Mİ?
#
#
# EVET İSE BOŞLUĞU HARFİ İLE DEĞİŞTİR.
#
#
# HAYIR İSE 1 CAN KAYBET VE CANI MI BİTTİ SOR
# . EVET İSE GAME OVER
# .HAYIR İSE (KULLANICIDAN TAHMİN ETMESİNİ İSTEYİN..) AŞAMASINA DÖN
#
# TÜM BOŞLUKLAR DOLU MU?
# EVET İSE OYUN BİTTİ
# HAYIR İSE (KULLANICIDAN TAHMİN ETMESİNİ İSTEYİN..) AŞAMASINA DÖN

# %% [markdown]
# #TODO-1 - Word_list'ten rastgele bir sözcük seçin ve bunu selected_word adlı bir değişkene atayın.
#
# #TODO-2 - Kullanıcıdan bir harf tahmin etmesini ve yanıtını tahmin adlı bir değişkene atamasını isteyin. Küçük harfle tahmin et.
#
# #TODO-3 - Kullanıcının tahmin ettiği (tahmin ettiği) harfin seçilen_kelimedeki harflerden biri olup olmadığını kontrol edin.

# %%
import random

# %%
word_list = ["ardvark", "baboon", "camel"]
select_word=(random.choice(word_list))

tahmin=input("tahmin edeceğiniz kelimeyi girin : ").lower()
#print(type(word_list))
#print(type(select_word))
#print(word_list)
#print(select_word)
listem=list(select_word)
#print(listem)

for i in listem:
    if i==tahmin:
        print("var")
    else:
        print("yok")
# Out:
# yok
# var
# yok
# yok
# yok

# %% [markdown]
# TODO-1: - Ekran adında boş bir Liste oluşturun.
# #Seçilen_sözcükteki her harf için 'görüntülemeye' bir "_" ekleyin.
# #Öyleyse seçilen_kelime "apple" ise, tahmin edilecek her harfi temsil eden 5 "_" ile ekran ["_", "_", "_", "_", "_"] şeklinde olmalıdır.
#
#
# TODO-2: - Seçilen_kelimedeki her bir konum arasında döngü yapın;
# #Eğer o konumdaki harf 'tahmin et' ile eşleşirse, ekranda o konumdaki o harfi gösterin.
# #Örneğin. Kullanıcı "p" kelimesini tahmin ederse ve seçilen kelime "apple" ise, ekran ["_", "p", "p", "_", "_"] olmalıdır.
# için
#
#
# #TODO-3: - 'Ekran'ı yazdırın ve tahmin edilen harfi doğru konumda görmeli ve diğer tüm harfleri "_" ile değiştirmelisiniz.
# #İpucu - Kullanıcının bir sonraki harfi tahmin etmesini sağlama konusunda endişelenmeyin. Bunu 3. adımda ele alacağız.

# %%
word_list = ["ardvark", "baboon", "camel"]
select_word=(random.choice(word_list))

ekran=[]
print(select_word)
for i in select_word:
    ekran+="-"
print(ekran)

listeler=list(select_word)
print(listeler)
tahmin=input("tahmin edeceğiniz kelimeyi girin : ").lower()

uzunluk = len(listeler)
print(uzunluk)
for i in range(uzunluk):
    if listeler[i]==tahmin:
        ekran[i]=listeler[i]
    else:
        continue
        
print(ekran)
ekran=[]
print("en son boş" , ekran)
# Out:
# camel
# ['-', '-', '-', '-', '-']
# ['c', 'a', 'm', 'e', 'l']
# 5
# ['-', 'a', '-', '-', '-']
# en son boş []

# %% [markdown]
# #TODO-1: - Kullanıcının tekrar tahmin etmesi için bir while döngüsü kullanın. Döngü yalnızca, kullanıcı seçilen_sözcükteki tüm harfleri tahmin ettiğinde ve 'ekran'da artık boşluk ("_") kalmadığında durmalıdır. Ardından kullanıcıya kazandığını söyleyebilirsiniz.

# %% [markdown]
# #YAPILACAK-1: - Kalan can sayısını takip etmek için 'canlar' adlı bir değişken oluşturun.
# #'canları' 6'ya eşitle
#
# YAPILACAK-2: - Seçilen_kelimede tahmin bir harf değilse,
#      #Sonra 'canları' 1 azalt.
#      #Eğer canlar 0'a düşerse oyun durmalı ve "Kaybettin" yazmalıdır.
#
#
# #TODO-3: - ASCII resmini, kullanıcının kalan mevcut 'yaşam' sayısına karşılık gelen 'aşamalardan' yazdırın.

# %%
import random

stages = ['''
  +---+
  |   |
  O   |
 /|\  |
 / \  |
      |
=========
''', '''
  +---+
  |   |
  O   |
 /|\  |
 /    |
      |
=========
''', '''
  +---+
  |   |
  O   |
 /|\  |
      |
      |
=========
''', '''
  +---+
  |   |
  O   |
 /|   |
      |
      |
=========''', '''
  +---+
  |   |
  O   |
  |   |
      |
      |
=========
''', '''
  +---+
  |   |
  O   |
      |
      |
      |
=========
''', '''
  +---+
  |   |
      |
      |
      |
      |
=========
''']

end_of_game = False
word_list = ["ardvark", "baboon", "camel"]
chosen_word = random.choice(word_list)
word_length = len(chosen_word)


lives = 6


print(chosen_word)


display = []
for _ in range(word_length):
    display += "_"

while not end_of_game:
    guess = input("Guess a letter: ").lower()

   
    for position in range(word_length):
        letter = chosen_word[position]
      
        if letter == guess:
            display[position] = letter

   
    if guess not in chosen_word:
        lives -= 1
        if lives == 0:
            end_of_game = True
            print("You lose.")

   
    print(f"{' '.join(display)}")

   
    if "_" not in display:
        end_of_game = True
        print("You win.")

    
    print(stages[lives])
# Out:
# baboon
# _ a _ _ _ _
#
#   +---+
#   |   |
#       |
#       |
#       |
#       |
# ...
#
# b a b _ _ _
#
#   +---+
#   |   |
#       |
#       |
#       |
#       |
# ...
#
# b a b o o _
#
#   +---+
#   |   |
#       |
#       |
#       |
#       |
# ...
#
# b a b o o n
# You win.
#
#   +---+
#   |   |
#       |
#       |
#       |
#       |
# ...

# %%
import random
import hangman_word
import hangman_art
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [3], line 2
#       1 import random
# ----> 2 import hangman_words
#       3 import hangman_art
#
# ModuleNotFoundError: No module named 'hangman_words'

# %%
import random



chosen_word = random.choice(word_list)
word_length = len(chosen_word)

end_of_game = False
lives = 6



from hangman_art import logo
print(logo)



print(f'Pssst, the solution is {chosen_word}.')



display = []
for _ in range(word_length):
    display += "_"

while not end_of_game:
    guess = input("Guess a letter: ").lower()

   

    if guess in display:
        print(f"You've already guessed {guess}")

    

    for position in range(word_length):
        letter = chosen_word[position]
        

        if letter == guess:
            display[position] = letter

   
    if guess not in chosen_word:
        

        print(f"You guessed {guess}, that's not in the word. You lose a life.")
        
        lives -= 1
        if lives == 0:
            end_of_game = True
            print("You lose.")

    

    print(f"{' '.join(display)}")

   

    if "_" not in display:
        end_of_game = True
        print("You win.")

    

    from hangman_art import stages
    print(stages[lives])
# Out:
#
#  _
# | |
# | |__   __ _ _ __   __ _ _ __ ___   __ _ _ __
# | '_ \ / _` | '_ \ / _` | '_ ` _ \ / _` | '_ \
# | | | | (_| | | | | (_| | | | | | | (_| | | | |
# |_| |_|\__,_|_| |_|\__, |_| |_| |_|\__,_|_| |_|
#                     __/ |
#                    |___/
# Pssst, the solution is caliph.
# _ a _ _ _ _
#
#   +---+
#   |   |
#       |
#       |
#       |
#       |
# ...
#
# You guessed b, that's not in the word. You lose a life.
# _ a _ _ _ _
#
#   +---+
#   |   |
#   O   |
#       |
#       |
#       |
# ...
#
# You guessed b, that's not in the word. You lose a life.
# _ a _ _ _ _
#
#   +---+
#   |   |
#   O   |
#   |   |
#       |
#       |
# ...
#
# You guessed x, that's not in the word. You lose a life.
# _ a _ _ _ _
#
#   +---+
#   |   |
#   O   |
#  /|   |
#       |
#       |
# ...
# You guessed s, that's not in the word. You lose a life.
# _ a _ _ _ _
#
#   +---+
#   |   |
#   O   |
#  /|\  |
#       |
#       |
# ...
#
# You guessed d, that's not in the word. You lose a life.
# _ a _ _ _ _
#
# ...
