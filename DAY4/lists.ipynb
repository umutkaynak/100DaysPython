# %%
# bir değişken içersisinde birden fazla değer tutabilen yapıdır.
fruits=["elma","armut"]
print(fruits)
# Out:
# ['elma', 'armut']

# %%
Turkey =["istanbul","adana","bartın","zonguldak","istanbul","adana","bartın","zonguldak"]
print(Turkey[0])
print(Turkey[2])
print(Turkey[3:7])

print("-------------------------")

print(Turkey[-1])
print(Turkey[-2])
# Out:
# istanbul
# bartın
# ['zonguldak', 'istanbul', 'adana', 'bartın']
# -------------------------
# zonguldak
# bartın

# %% [markdown]
# #birçok ilişkili veri parçasını saklamak için liste kullanılabilir.

# %%
Turkey[1]="Adana"
Turkey[1]
# Out:
# 'Adana'

# %%
#listenin sonuna ekleme yapma

Turkey.append("Suriye")
Turkey
# Out:
# ['istanbul',
#  'Adana',
#  'bartın',
#  'zonguldak',
#  'istanbul',
#  'adana',
#  'bartın',
#  'zonguldak',
#  'Suriye']

# %%
#listeye ek liste oluşturarak ekleme

Turkey.extend(["mısır","katar","rusya"])

# %%
Turkey
# Out:
# ['istanbul',
#  'Adana',
#  'bartın',
#  'zonguldak',
#  'istanbul',
#  'adana',
#  'bartın',
#  'zonguldak',
#  'Suriye',
#  'mısır',
#  'katar',
#  'rusya']

# %% [markdown]
# LİSTELERDE EN ÇOK KARŞILAŞILAN HATALARDAN BİRİ OLAN İNDEX ARALIK DIŞI HATASI OLARAK ADLANDIRILAN "IndexError: "

# %%
len(Turkey)
# Out:
# 12

# %%
Turkey[12]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_27/1498901118.py in <module>
# ----> 1 Turkey[12]
#
# IndexError: list index out of range

# %% [markdown]
# görüldüğü gibi index dışındaki bir değer ile arama yaptığımızda hata ile karşılaşıyoruz.

# %%
indeks=len(Turkey)
Turkey[indeks-1]
# Out:
# 'rusya'

# %% [markdown]
# burada var olan indeks sayısının int değere atayıp -1 eklediğimde son indeksi görebiliriz.

# %%
# Out:
# Kale
