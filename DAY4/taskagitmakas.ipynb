# %%
import random as rnd
x=rnd.randint(0,2)
print(x)
seçim=input("taş için 0 kağıt için 1 makas için 2 girin:")
if seçim=="0":
    if x==0:
        print("berabere")
    elif x==1:
        print("yenildiniz")
    elif x==2:
        print("kazandınız")
    else:
        print("geçersiz aralık")
        

if seçim=="1":
    if x==0:
        print("kazandınız")
    elif x==1:
        print("berabere")
    elif x==2:
        print("kaybettiniz")
    else:
        print("geçersiz aralık")
        
if seçim=="2":
    if x==0:
        print("kaybettiniz")
    elif x==1:
        print("kazandınız")
    elif x==2:
        print("berabere")
    else:
        print("geçersiz aralık")
# Out:
# 1
# taş için 0 kağıt için 1 makas için 2 girin: 2
# kazandınız

# %% [markdown]
# **BİR SORUNUN BİRDEN FAZLA ÇÖZÜMÜ OLABİLİR BİZ SADECE KOLAY OLAN ÇÖZÜMÜ ELE ALDIK **
