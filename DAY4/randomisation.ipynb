# %%
#rastgele sayı üretmek için kütüphanemizi import edelim
import random as rnd

# %%
rnd.randint(1,10)
# Out:
# 4

# %% [markdown]
# modül:kodumuz çoğunlukla aynı sayfada bir tür komut dosyası tarzında yazdığımız görüldü. bazen kod çok uzun olabilir. ve bu büyüklükte kodu anlamak zorlaşır.bu durumda yapılacak her kodu modül şeklinde yazmaktır. örneğin bir araç üretiminde lastik motor şase direksiyon gibi tüm işlemleri tek bir kişi tarafından yapılması imkansızdır , onun yerine bunları; lastik modülü, motor modülü, şase modülü vs. şeklinde modüllere bölünür. her şey birleştiriildiğinde ortaya bir ürün çıkar

# %% [markdown]
# kod şeklindeki doyalarımızı kodumuzun içine import edebiliyoruz . import my_module gibi.

# %%
#float tipinde random sayı üretme 0-1 arasında 
random_float= rnd.random()
print(random_float)
# Out:
# 0.4728644948619738

# %%
#0-5 arasında ondalıkla sayı üretme
randomBes= 5*(rnd.random())
print(randomBes)
# Out:
# 1.1311940898713964

# %%
# random sayı ile yazı tura gelme ihtimali
rast=rnd.randint(0,1)

if rast==1:
    print("yazı")
else:
    print("tura")
# Out:
# tura
